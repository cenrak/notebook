# %%
import tensorflow as tf

# %%
w = tf.Variable([3.4], tf.float32)
x = tf.placeholder(tf.float32)

outputs = w * x

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    
    print(sess.run(outputs, {x: [2]}))
# Out:
# [ 6.80000019]
